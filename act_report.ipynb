# %% [markdown]
# # Twitter users activity on WeRateDogs Portal
#
# #### Data Analysis & Visualization
#
# I downloaded the Twitter data for the WeRateDogs website. The final dataset contained 1990 tweets. My first major focus went on with the retweet and favorites count.

# %%
from IPython.display import Image
Image(filename='scatterplot.png')

# %% [markdown]
# I checked for a scatter plot between Retweets and Favorites. It clearly shows from below that they both follow a similar trend and go in sync together.
# There is a very strong relationship between retweet and favorite counts. As the user shows interest on Favorites, one can expect to see Retweets to increase and vice versa.

# %%
from IPython.display import Image
Image(filename='dog_names.png')

# %% [markdown]
# Majority of dog names are none.Followed by Charlie,Oliver, Tucker,  and so on..

# %%
from IPython.display import Image
Image(filename='dog_stage.png')

# %% [markdown]
# Most of the dog stage names are none. Pupper is more common dog state names as compared to other not none stage names.
